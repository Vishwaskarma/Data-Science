# %%
## range
print(range(5))
# Out:
# range(0, 5)

# %%
## for Loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
range(1,10,1)
# Out:
# range(1, 10)

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
print(range(1,10,3))
# Out:
# range(1, 10, 3)

# %%
## string
str="himanshu"
for i in str:
  print(i)
# Out:
# h
# i
# m
# a
# n
# s
# h
# u

# %%
count=0
while count<5:
    print(count)
    count=count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count=0
while count<5:
    print(count)
    count=count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## Loop control statements
## break
## the break statements exits the loop permaturely


## break statement

for i in range(10):
    if i==8:
        break 
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
## continu statement
## the continue statement skips the current iteration and continue with the next

for i in range(10):
    if i==5:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
## pass 
## the pass ststaement is a null operation; it does nothing.

for i in range(5):
    if i==3:
        pass 
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## nested loops
##  a loops inside loop

for i in range(3):
    for j in range(2):
        print(f"i:{i} and j:{j}")
# Out:
# i:0 and j:0
# i:0 and j:1
# i:1 and j:0
# i:1 and j:1
# i:2 and j:0
# i:2 and j:1

# %%
## example calculate the sum of n natural numbers
## while  loop
n=10
sum=0
count=1

while count<=n:
    sum=sum+count
    count=count+1

    print("sum of first 10 natural number:",sum)
# Out:
# sum of first 10 natural number: 1
# sum of first 10 natural number: 3
# sum of first 10 natural number: 6
# sum of first 10 natural number: 10
# sum of first 10 natural number: 15
# sum of first 10 natural number: 21
# sum of first 10 natural number: 28
# sum of first 10 natural number: 36
# sum of first 10 natural number: 45
# sum of first 10 natural number: 55

# %%
n=10
sum=0
for i in range(11):
    sum=sum+i
    print(sum)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
## exmple - prime number from 1 to hundread
for num in range(1,101):
    if num>1:
        for i in range(2,num):
            if num%i==0:
                break
            else:
                print(num)
# Out:
# 3
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 15
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 21
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 25
# 25
# 25
# 27
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 33
# 35
# 35
# 35
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 39
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# ...
